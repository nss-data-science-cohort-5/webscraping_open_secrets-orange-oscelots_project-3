# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import requests
from bs4 import BeautifulSoup as BS

# %matplotlib inline

# %%
brit_url = 'https://www.britannica.com/topic/United-States-House-of-Representatives-Seats-by-State-1787120'

response = requests.get(brit_url)

response
# Out:
# <Response [200]>

# %%
soup = BS(response.text)

districts = pd.read_html(str(soup.find('table')))[0]

districts.head()
# Out:
#         state  representatives
# 0     Alabama                7
# 1      Alaska                1
# 2     Arizona                9
# 3    Arkansas                4
# 4  California               53

# %% [markdown]
# ### Webscraping https://worldpopulationreview.com/states/state-abbreviations to get abbreviations

# %%
abbrev_url = 'https://worldpopulationreview.com/states/state-abbreviations'

abbrev_response = requests.get(abbrev_url)

response
# Out:
# <Response [200]>

# %%
soup = BS(abbrev_response.text)

abbrev = pd.read_html(str(soup.find('table')))[0]

# %%
abbrev
# Out:
#                    State Abbreviation Code
# 0                Alabama         Ala.   AL
# 1                 Alaska       Alaska   AK
# 2                Arizona        Ariz.   AZ
# 3               Arkansas         Ark.   AR
# 4             California       Calif.   CA
# 5               Colorado        Colo.   CO
# 6            Connecticut        Conn.   CT
# 7               Delaware         Del.   DE
# 8   District of Columbia         D.C.   DC
# 9                Florida         Fla.   FL
# 10               Georgia          Ga.   GA
# 11                Hawaii       Hawaii   HI
# 12                 Idaho        Idaho   ID
# 13              Illinois         Ill.   IL
# 14               Indiana         Ind.   IN
# 15                  Iowa         Iowa   IA
# 16                Kansas        Kans.   KS
# 17              Kentucky          Ky.   KY
# 18             Louisiana          La.   LA
# 19                 Maine        Maine   ME
# 20              Maryland          Md.   MD
# ...

# %%
districts = districts.merge(abbrev,
                           left_on = 'state',
                           right_on = 'State')

# %%
districts = districts.drop(['State', 'Abbreviation'],
                           axis = 1)

# %%
districts.to_csv('../data/district_info.csv',
                index = False)
